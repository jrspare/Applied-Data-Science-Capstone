# %% [markdown]
# # Applied Data Science Capstone - Week 3

# %% [markdown]
# ### Peer-graded Assignment: Segmenting and Clustering Neighbourhoods in Toronto

# %% [markdown]
# ###### Q1
# First, we scrape the postal code data from a given Wikipedia page and then transform it into a pandas dataframe.

# %%
# Import Libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Get the table of postal codes from the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text
Canada_data = BeautifulSoup(source, 'lxml')

# %%
# Create a new Pandas DataFrame
column_names = ['Postalcode','Borough','Neighborhood']
Toronto = pd.DataFrame(columns = column_names)

# %%
# Loop through to find postcode, borough, neighborhood 
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    Toronto = Toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %%
Toronto.head
# Out:
# <bound method NDFrame.head of     Postalcode           Borough  \
# 0            0                 0
# 1          M1A      Not assigned
# 2          M2A      Not assigned
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# 6          M6A        North York
# 7          M6A        North York
# 8          M7A  Downtown Toronto
# 9          M8A      Not assigned
# 10         M9A         Etobicoke
# 11         M1B       Scarborough
# 12         M1B       Scarborough
# 13         M2B      Not assigned
# 14         M3B        North York
# 15         M4B         East York
# 16         M4B         East York
# 17         M5B  Downtown Toronto
# 18         M5B  Downtown Toronto
# 19         M6B        North York
# 20         M7B      Not assigned
# 21         M8B      Not assigned
# 22         M9B         Etobicoke
# 23         M9B         Etobicoke
# 24         M9B         Etobicoke
# 25         M9B         Etobicoke
# 26         M9B         Etobicoke
# 27         M1C       Scarborough
# 28         M1C       Scarborough
# 29         M1C       Scarborough
# ..         ...               ...
# 258        M9X      Not assigned
# 259        M1Y      Not assigned
# 260        M2Y      Not assigned
# 261        M3Y      Not assigned
# 262        M4Y  Downtown Toronto
# 263        M5Y      Not assigned
# 264        M6Y      Not assigned
# 265        M7Y      East Toronto
# 266        M8Y         Etobicoke
# 267        M8Y         Etobicoke
# 268        M8Y         Etobicoke
# 269        M8Y         Etobicoke
# 270        M8Y         Etobicoke
# 271        M8Y         Etobicoke
# 272        M8Y         Etobicoke
# 273        M8Y         Etobicoke
# 274        M9Y      Not assigned
# 275        M1Z      Not assigned
# 276        M2Z      Not assigned
# 277        M3Z      Not assigned
# 278        M4Z      Not assigned
# 279        M5Z      Not assigned
# 280        M6Z      Not assigned
# 281        M7Z      Not assigned
# 282        M8Z         Etobicoke
# 283        M8Z         Etobicoke
# 284        M8Z         Etobicoke
# 285        M8Z         Etobicoke
# 286        M8Z         Etobicoke
# 287        M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                    0
# 1                                         Not assigned
# 2                                         Not assigned
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Queen's Park
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]>

# %%
# Clean Pandas DataFrame 
Toronto = Toronto[Toronto.Borough!='Not assigned']
Toronto = Toronto[Toronto.Borough!= 0]
Toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,Toronto.shape[0]):
    if Toronto.iloc[i][2] == 'Not assigned':
        Toronto.iloc[i][2] = Toronto.iloc[i][1]
        i = i+1
                                 
df = Toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# Next, we clean our data:

# %%
# Drop rows with a "Not assigned" value:
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]
df.head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

# %%
print(df2.shape)
df2.head()
# Out:
# (103, 3)
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ###### Q2
# We will use the Geocoder Python package to get the latitude and the longitude coordinates of each neighborhood.
#
# Given that this package can be very unreliable, we will run a while loop for each postal code, to make sure that we get the coordinates for all of our neighborhoods.

# %%
# Install GeoCoder if not already installed
# !conda install -c conda-forge geocoder --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     geocoder:        1.38.1-py_1       conda-forge
#     ratelim:         0.1.6-py_2        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# ratelim-0.1.6        | 6 KB      | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# geocoder-1.38.1      | 53 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import geocoder # import geocoder


def get_latlng(postal_code):
# initialize your variable to None
    lat_lng_coords = None

# loop until you get the coordinates
    while(lat_lng_coords is None):
      g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
      lat_lng_coords = g.latlng
    return lat_lng_coords
    
# test get_latlng()
get_latlng('M1B')
# Out:
# [43.811525000000074, -79.19551746399998]

# %%
# Retrive Postal Code coordinates
postal_codes = df2['Postalcode']    
coords = [ get_latlng(postal_code) for postal_code in postal_codes.tolist() ]

# %%
# Add Lat and Long columns
coords_df2 = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df2['Latitude'] = coords_df2['Latitude']
df2['Longitude'] = coords_df2['Longitude']

# %%
# test
df2[df2.Postalcode == 'M1B']
# Out:
#   Postalcode      Borough    Neighborhood   Latitude  Longitude
# 0        M1B  Scarborough  Rouge, Malvern  43.811525 -79.195517

# %%
df2.head()
# Out:
#   Postalcode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.811525
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.785665
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.765815
# 3        M1G  Scarborough                                  Woburn  43.768369
# 4        M1H  Scarborough                               Cedarbrae  43.769688
#
#    Longitude
# 0 -79.195517
# 1 -79.158725
# 2 -79.175193
# 3 -79.217590
# 4 -79.239440

# %% [markdown]
# ###### Q3
# Clustering

# %%
import numpy as np   # Library to handle data in a vectorized manner
import json          # Library to handle JSON files

# !conda install -c conda-forge geopy --yes # Install geopy if not already installed
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0   conda-forge
#     geopy:         1.21.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df2['Latitude'], df2['Longitude'], df2['Borough'], df2['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
scarborough_data = df2[df2['Borough'] == 'Scarborough'].reset_index(drop=True)
address1 = 'Scarborough,Toronto'

geolocator1 = Nominatim()
location1 = geolocator1.geocode(address1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of Scarborough are {}, {}.'.format(latitude1, longitude1))
# Out:
# The geograpical coordinate of Scarborough are 43.773077, -79.257774.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.

# %%
map_scarb = folium.Map(location=[latitude1, longitude1], zoom_start=11)

# add markers to map
for lat, lng, label in zip(scarborough_data['Latitude'], scarborough_data['Longitude'], scarborough_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_scarb)  
    
map_scarb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# The code was removed by Watson Studio for sharing.

# %%
neighborhood_latitude = scarborough_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = scarborough_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = scarborough_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))

LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, radius, LIMIT)
# Out:
# Latitude and longitude values of Rouge, Malvern are 43.811525000000074, -79.19551746399998.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
results = requests.get(url).json()
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(12)
# Out:
#                             name          categories        lat        lng
# 0                        SEPHORA      Cosmetics Shop  43.775017 -79.258109
# 1                   Disney Store    Toy / Game Store  43.775537 -79.256833
# 2      American Eagle Outfitters      Clothing Store  43.776012 -79.258334
# 3       St. Andrews Fish & Chips   Fish & Chips Shop  43.771865 -79.252645
# 4                 Tommy Hilfiger      Clothing Store  43.776015 -79.257369
# 5                      DAVIDsTEA            Tea Room  43.776320 -79.258688
# 6         Chipotle Mexican Grill  Mexican Restaurant  43.776410 -79.258069
# 7                      Hot Topic      Clothing Store  43.775450 -79.257929
# 8   Coliseum Scarborough Cinemas       Movie Theater  43.775995 -79.255649
# 9             Shoppers Drug Mart            Pharmacy  43.773305 -79.251662
# 10                   Tim Hortons         Coffee Shop  43.769936 -79.260368
# 11       Scarborough Town Centre       Shopping Mall  43.775277 -79.257413

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 42 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
scarborough_venues = getNearbyVenues(names=scarborough_data['Neighborhood'],
                                   latitudes=scarborough_data['Latitude'],
                                   longitudes=scarborough_data['Longitude']
                                  )
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West
# Upper Rouge

# %%
print(scarborough_venues.shape)
scarborough_venues.head()
# Out:
# (89, 7)
#                              Neighborhood  Neighborhood Latitude  \
# 0  Highland Creek, Rouge Hill, Port Union              43.785665
# 1  Highland Creek, Rouge Hill, Port Union              43.785665
# 2       Guildwood, Morningside, West Hill              43.765815
# 3       Guildwood, Morningside, West Hill              43.765815
# 4       Guildwood, Morningside, West Hill              43.765815
#
#    Neighborhood Longitude                           Venue  Venue Latitude  \
# 0              -79.158725  Scarborough Historical Society       43.788755
# 1              -79.158725           Royal Canadian Legion       43.782533
# 2              -79.175193        Homestead Roofing Repair       43.765140
# 3              -79.175193     Heron Park Community Centre       43.768867
# 4              -79.175193                      Heron Park       43.769327
#
#    Venue Longitude              Venue Category
# 0       -79.162438              History Museum
# 1       -79.163085                         Bar
# 2       -79.178663  Construction & Landscaping
# 3       -79.176958        Gym / Fitness Center
# 4       -79.177201                        Park

# %%
print('There are {} uniques categories.'.format(len(scarborough_venues['Venue Category'].unique())))
# Out:
# There are 50 uniques categories.

# %%
scarborough_venues.head(3)
print(scarborough_venues.groupby('Neighborhood').count()[:4])
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Agincourt                                                              15
# Agincourt North, L'Amoreaux East, Milliken, Ste...                      2
# Birch Cliff, Cliffside West                                             6
# Cedarbrae                                                               2
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                               15
# Agincourt North, L'Amoreaux East, Milliken, Ste...                       2
# Birch Cliff, Cliffside West                                              6
# Cedarbrae                                                                2
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                              15              15
# Agincourt North, L'Amoreaux East, Milliken, Ste...      2               2
# Birch Cliff, Cliffside West                             6               6
# Cedarbrae                                               2               2
#
#                                                     Venue Longitude  \
# Neighborhood
# Agincourt                                                        15
# Agincourt North, L'Amoreaux East, Milliken, Ste...                2
# Birch Cliff, Cliffside West                                       6
# Cedarbrae                                                         2
#
#                                                     Venue Category
# Neighborhood
# Agincourt                                                       15
# Agincourt North, L'Amoreaux East, Milliken, Ste...               2
# Birch Cliff, Cliffside West                                      6
# Cedarbrae                                                        2

# %%
# one hot encoding
scarb_onehot = pd.get_dummies(scarborough_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
scarb_onehot['Neighborhood'] = scarborough_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [scarb_onehot.columns[-1]] + list(scarb_onehot.columns[:-1])
scarb_onehot = scarb_onehot[fixed_columns]

scarb_grouped = scarb_onehot.groupby('Neighborhood').mean().reset_index()

# %%
scarb_onehot.shape
# Out:
# (89, 51)

# %%
scarb_grouped = scarb_onehot.groupby('Neighborhood').mean().reset_index()
scarb_grouped
# Out:
#                                          Neighborhood  Auto Garage    Bakery  \
# 0                                           Agincourt          0.0  0.066667
# 1   Agincourt North, L'Amoreaux East, Milliken, St...          0.0  0.000000
# 2                         Birch Cliff, Cliffside West          0.0  0.000000
# 3                                           Cedarbrae          0.0  0.000000
# 4                     Clairlea, Golden Mile, Oakridge          0.0  0.200000
# 5             Clarks Corners, Sullivan, Tam O'Shanter          0.0  0.000000
# 6     Cliffcrest, Cliffside, Scarborough Village West          0.0  0.000000
# 7   Dorset Park, Scarborough Town Centre, Wexford ...          0.0  0.250000
# 8         East Birchmount Park, Ionview, Kennedy Park          0.0  0.000000
# 9                   Guildwood, Morningside, West Hill          0.0  0.000000
# 10             Highland Creek, Rouge Hill, Port Union          0.0  0.000000
# 11                                    L'Amoreaux West          0.0  0.000000
# 12                                  Maryvale, Wexford          0.5  0.000000
# 13                                Scarborough Village          0.0  0.000000
# 14                                             Woburn          0.0  0.000000
#
#         Bank  Bar    Bistro  Brewery  Bus Line  Bus Station  Business Service  \
# 0   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 1   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 2   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 3   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 4   0.000000  0.0  0.000000     0.00       0.2          0.1              0.00
# 5   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 6   0.142857  0.0  0.142857     0.00       0.0          0.0              0.00
# 7   0.000000  0.0  0.000000     0.25       0.0          0.0              0.00
# 8   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 9   0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 10  0.000000  0.5  0.000000     0.00       0.0          0.0              0.00
# 11  0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 12  0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 13  0.000000  0.0  0.000000     0.00       0.0          0.0              0.00
# 14  0.000000  0.0  0.000000     0.00       0.0          0.0              0.25
#
#     ...  Shanghai Restaurant  Shopping Mall  Skating Rink  Soccer Field  \
# 0   ...             0.066667       0.133333      0.066667           0.0
# 1   ...             0.000000       0.000000      0.000000           0.0
# 2   ...             0.000000       0.000000      0.166667           0.0
# 3   ...             0.000000       0.000000      0.000000           0.0
# 4   ...             0.000000       0.000000      0.000000           0.1
# 5   ...             0.000000       0.090909      0.000000           0.0
# 6   ...             0.000000       0.000000      0.000000           0.0
# 7   ...             0.000000       0.000000      0.000000           0.0
# 8   ...             0.000000       0.000000      0.000000           0.0
# 9   ...             0.000000       0.000000      0.000000           0.0
# 10  ...             0.000000       0.000000      0.000000           0.0
# 11  ...             0.000000       0.000000      0.000000           0.0
# 12  ...             0.000000       0.000000      0.000000           0.0
# 13  ...             0.000000       0.000000      0.000000           0.0
# 14  ...             0.000000       0.000000      0.000000           0.0
#
#     Supermarket  Sushi Restaurant  Thai Restaurant  Trail  Train Station  \
# 0      0.066667          0.066667         0.000000    0.0           0.00
# 1      0.000000          0.000000         0.000000    0.0           0.00
# 2      0.000000          0.000000         0.000000    0.0           0.00
# 3      0.000000          0.000000         0.000000    0.5           0.00
# 4      0.000000          0.000000         0.000000    0.0           0.00
# 5      0.000000          0.000000         0.090909    0.0           0.00
# 6      0.000000          0.000000         0.000000    0.0           0.00
# 7      0.000000          0.000000         0.000000    0.0           0.00
# 8      0.000000          0.000000         0.000000    0.0           0.00
# 9      0.000000          0.000000         0.000000    0.0           0.00
# 10     0.000000          0.000000         0.000000    0.0           0.00
# 11     0.000000          0.000000         0.000000    0.0           0.00
# 12     0.000000          0.000000         0.000000    0.0           0.00
# 13     0.000000          0.000000         0.000000    0.0           0.25
# 14     0.000000          0.000000         0.000000    0.0           0.00
#
#     Vietnamese Restaurant
# 0                0.066667
# 1                0.000000
# 2                0.000000
# 3                0.000000
# 4                0.000000
# 5                0.000000
# 6                0.000000
# 7                0.000000
# 8                0.000000
# 9                0.000000
# 10               0.000000
# 11               0.000000
# 12               0.000000
# 13               0.000000
# 14               0.000000
#
# [15 rows x 51 columns]

# %%
scarb_grouped.shape
# Out:
# (15, 51)

# %% [markdown]
# ###### Top 5 most common venues per neighbourhood

# %%
num_top_venues = 5

for hood in scarb_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = scarb_grouped[scarb_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                 venue  freq
# 0  Chinese Restaurant  0.13
# 1       Shopping Mall  0.13
# 2        Skating Rink  0.07
# 3    Department Store  0.07
# 4                Pool  0.07
#
#
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
#                   venue  freq
# 0              Pharmacy   1.0
# 1           Auto Garage   0.0
# 2                  Pool   0.0
# 3  Hong Kong Restaurant   0.0
# 4     Indian Restaurant   0.0
#
#
# ----Birch Cliff, Cliffside West----
#                    venue  freq
# 0               Gym Pool  0.17
# 1                    Gym  0.17
# 2           Skating Rink  0.17
# 3  General Entertainment  0.17
# 4                   Park  0.17
#
#
# ----Cedarbrae----
#                   venue  freq
# 0                 Trail   0.5
# 1            Playground   0.5
# 2           Auto Garage   0.0
# 3                  Pool   0.0
# 4  Hong Kong Restaurant   0.0
#
#
# ----Clairlea, Golden Mile, Oakridge----
#            venue  freq
# 0         Bakery   0.2
# 1   Intersection   0.2
# 2       Bus Line   0.2
# 3  Metro Station   0.1
# 4    Bus Station   0.1
#
#
# ----Clarks Corners, Sullivan, Tam O'Shanter----
#                 venue  freq
# 0            Pharmacy  0.18
# 1         Pizza Place  0.18
# 2          Hobby Shop  0.09
# 3     Thai Restaurant  0.09
# 4  Chinese Restaurant  0.09
#
#
# ----Cliffcrest, Cliffside, Scarborough Village West----
#             venue  freq
# 0  Discount Store  0.14
# 1            Bank  0.14
# 2          Bistro  0.14
# 3        Pharmacy  0.14
# 4       Gift Shop  0.14
#
#
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
#                         venue  freq
# 0                      Bakery  0.25
# 1                     Brewery  0.25
# 2                   Gift Shop  0.25
# 3  Construction & Landscaping  0.25
# 4                 Auto Garage  0.00
#
#
# ----East Birchmount Park, Ionview, Kennedy Park----
#               venue  freq
# 0    Discount Store   0.4
# 1        Hobby Shop   0.2
# 2       Coffee Shop   0.2
# 3  Department Store   0.2
# 4              Pool   0.0
#
#
# ----Guildwood, Morningside, West Hill----
#                         venue  freq
# 0        Gym / Fitness Center  0.33
# 1                        Park  0.33
# 2  Construction & Landscaping  0.33
# 3                 Auto Garage  0.00
# 4                        Pool  0.00
#
#
# ----Highland Creek, Rouge Hill, Port Union----
#                venue  freq
# 0     History Museum   0.5
# 1                Bar   0.5
# 2         Restaurant   0.0
# 3  Indian Restaurant   0.0
# 4       Intersection   0.0
#
#
# ----L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1    Chinese Restaurant  0.17
# 2        Sandwich Place  0.08
# 3  Other Great Outdoors  0.08
# 4         Grocery Store  0.08
#
#
# ----Maryvale, Wexford----
#                venue  freq
# 0        Auto Garage   0.5
# 1  Convenience Store   0.5
# 2  Indian Restaurant   0.0
# 3       Intersection   0.0
# 4  Korean Restaurant   0.0
#
#
# ----Scarborough Village----
#                venue  freq
# 0         Restaurant  0.25
# 1      Train Station  0.25
# 2  Indian Restaurant  0.25
# 3      Grocery Store  0.25
# 4               Pool  0.00
#
#
# ----Woburn----
#                venue  freq
# 0  Korean Restaurant  0.25
# 1               Park  0.25
# 2   Business Service  0.25
# 3        Coffee Shop  0.25
# 4        Auto Garage  0.00

# %% [markdown]
# ###### Dataframe of the top 10 venues for each neighborhood

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = scarb_grouped['Neighborhood']

for ind in np.arange(scarb_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(scarb_grouped.iloc[ind, :], num_top_venues)
    
neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                          Agincourt         Shopping Mall
# 1  Agincourt North, L'Amoreaux East, Milliken, St...              Pharmacy
# 2                        Birch Cliff, Cliffside West              Gym Pool
# 3                                          Cedarbrae            Playground
# 4                    Clairlea, Golden Mile, Oakridge                Bakery
#
#    2nd Most Common Venue       3rd Most Common Venue 4th Most Common Venue  \
# 0     Chinese Restaurant       Vietnamese Restaurant      Department Store
# 1  Vietnamese Restaurant  Construction & Landscaping         Grocery Store
# 2           Skating Rink       General Entertainment                  Park
# 3                  Trail             College Stadium         Grocery Store
# 4               Bus Line                Intersection          Soccer Field
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0  Hong Kong Restaurant                   Park                  Pool
# 1             Gift Shop  General Entertainment   Fried Chicken Joint
# 2       College Stadium                    Gym                  Bank
# 3             Gift Shop  General Entertainment   Fried Chicken Joint
# 4           Bus Station            Coffee Shop         Metro Station
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Shanghai Restaurant         Grocery Store           Skating Rink
# 1   Fast Food Restaurant        Discount Store       Department Store
# 2          Grocery Store             Gift Shop                 Bakery
# 3   Fast Food Restaurant        Discount Store       Department Store
# 4  Vietnamese Restaurant        Cosmetics Shop              Gift Shop

# %% [markdown]
# ###### Run K-Means with 5 clusters

# %%
scarb_data = scarborough_data.drop(16)
# set number of clusters
kclusters = 5

scarb_grouped_clustering = scarb_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(scarb_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 0, 3, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

scarb_merged = scarb_data


# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
scarb_merged = scarb_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

scarb_merged.head() # check the last columns!
# Out:
#   Postalcode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.811525
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.785665
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.765815
# 3        M1G  Scarborough                                  Woburn  43.768369
# 4        M1H  Scarborough                               Cedarbrae  43.769688
#
#    Longitude  Cluster Labels       1st Most Common Venue  \
# 0 -79.195517             NaN                         NaN
# 1 -79.158725             4.0              History Museum
# 2 -79.175193             0.0  Construction & Landscaping
# 3 -79.217590             0.0           Korean Restaurant
# 4 -79.239440             3.0                  Playground
#
#   2nd Most Common Venue       3rd Most Common Venue  4th Most Common Venue  \
# 0                   NaN                         NaN                    NaN
# 1                   Bar  Construction & Landscaping                    Gym
# 2                  Park        Gym / Fitness Center  Vietnamese Restaurant
# 3      Business Service                 Coffee Shop                   Park
# 4                 Trail             College Stadium          Grocery Store
#
#    5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 0                    NaN                    NaN                    NaN
# 1          Grocery Store              Gift Shop  General Entertainment
# 2          Grocery Store              Gift Shop  General Entertainment
# 3  Vietnamese Restaurant      Convenience Store          Grocery Store
# 4              Gift Shop  General Entertainment    Fried Chicken Joint
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0                   NaN                    NaN                    NaN
# 1   Fried Chicken Joint   Fast Food Restaurant         Discount Store
# 2   Fried Chicken Joint   Fast Food Restaurant         Discount Store
# 3             Gift Shop  General Entertainment    Fried Chicken Joint
# 4  Fast Food Restaurant         Discount Store       Department Store

# %%
scarb_merged['Cluster Labels'].isna().sum()
# Out:
# 1

# %%
scarb_merged_cleaned = scarb_merged.drop(scarb_merged.index[0])
scarb_merged_cleaned['Cluster Labels'].isna().sum()
# Out:
# 0

# %%
scarb_merged_cleaned.head()
# Out:
#   Postalcode      Borough                            Neighborhood   Latitude  \
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.785665
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.765815
# 3        M1G  Scarborough                                  Woburn  43.768369
# 4        M1H  Scarborough                               Cedarbrae  43.769688
# 5        M1J  Scarborough                     Scarborough Village  43.743125
#
#    Longitude  Cluster Labels       1st Most Common Venue  \
# 1 -79.158725             4.0              History Museum
# 2 -79.175193             0.0  Construction & Landscaping
# 3 -79.217590             0.0           Korean Restaurant
# 4 -79.239440             3.0                  Playground
# 5 -79.231750             0.0               Train Station
#
#   2nd Most Common Venue       3rd Most Common Venue  4th Most Common Venue  \
# 1                   Bar  Construction & Landscaping                    Gym
# 2                  Park        Gym / Fitness Center  Vietnamese Restaurant
# 3      Business Service                 Coffee Shop                   Park
# 4                 Trail             College Stadium          Grocery Store
# 5         Grocery Store           Indian Restaurant             Restaurant
#
#         5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 1               Grocery Store              Gift Shop  General Entertainment
# 2               Grocery Store              Gift Shop  General Entertainment
# 3       Vietnamese Restaurant      Convenience Store          Grocery Store
# 4                   Gift Shop  General Entertainment    Fried Chicken Joint
# 5  Construction & Landscaping              Gift Shop  General Entertainment
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 1   Fried Chicken Joint   Fast Food Restaurant         Discount Store
# 2   Fried Chicken Joint   Fast Food Restaurant         Discount Store
# 3             Gift Shop  General Entertainment    Fried Chicken Joint
# 4  Fast Food Restaurant         Discount Store       Department Store
# 5   Fried Chicken Joint   Fast Food Restaurant         Discount Store

# %% [markdown]
# ###### Visualize clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(scarb_merged_cleaned['Latitude'], scarb_merged_cleaned['Longitude'], scarb_merged_cleaned['Neighborhood'], scarb_merged_cleaned['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color = rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###### Examine each cluster

# %%
scarb_merged_cleaned.loc[scarb_merged_cleaned['Cluster Labels'] == 0, scarb_merged_cleaned.columns[[1] + list(range(5, scarb_merged_cleaned.shape[1]))]]
# Out:
#         Borough  Cluster Labels       1st Most Common Venue  \
# 2   Scarborough             0.0  Construction & Landscaping
# 3   Scarborough             0.0           Korean Restaurant
# 5   Scarborough             0.0               Train Station
# 6   Scarborough             0.0              Discount Store
# 7   Scarborough             0.0                      Bakery
# 8   Scarborough             0.0                    Pharmacy
# 9   Scarborough             0.0                    Gym Pool
# 10  Scarborough             0.0                      Bakery
# 12  Scarborough             0.0               Shopping Mall
# 13  Scarborough             0.0                 Pizza Place
# 15  Scarborough             0.0        Fast Food Restaurant
#
#    2nd Most Common Venue  3rd Most Common Venue       4th Most Common Venue  \
# 2                   Park   Gym / Fitness Center       Vietnamese Restaurant
# 3       Business Service            Coffee Shop                        Park
# 5          Grocery Store      Indian Restaurant                  Restaurant
# 6             Hobby Shop       Department Store                 Coffee Shop
# 7               Bus Line           Intersection                Soccer Field
# 8                   Bank              Gift Shop                      Bistro
# 9           Skating Rink  General Entertainment                        Park
# 10             Gift Shop                Brewery  Construction & Landscaping
# 12    Chinese Restaurant  Vietnamese Restaurant            Department Store
# 13              Pharmacy            Coffee Shop             Thai Restaurant
# 15    Chinese Restaurant          Grocery Store              Cosmetics Shop
#
#          5th Most Common Venue       6th Most Common Venue  \
# 2                Grocery Store                   Gift Shop
# 3        Vietnamese Restaurant           Convenience Store
# 5   Construction & Landscaping                   Gift Shop
# 6        Vietnamese Restaurant  Construction & Landscaping
# 7                  Bus Station                 Coffee Shop
# 8               Discount Store              Sandwich Place
# 9              College Stadium                         Gym
# 10       Vietnamese Restaurant           Convenience Store
# 12        Hong Kong Restaurant                        Park
# 13         Fried Chicken Joint                  Hobby Shop
# 15              Sandwich Place                 Coffee Shop
#
#     7th Most Common Venue  8th Most Common Venue  9th Most Common Venue  \
# 2   General Entertainment    Fried Chicken Joint   Fast Food Restaurant
# 3           Grocery Store              Gift Shop  General Entertainment
# 5   General Entertainment    Fried Chicken Joint   Fast Food Restaurant
# 6           Grocery Store              Gift Shop  General Entertainment
# 7           Metro Station  Vietnamese Restaurant         Cosmetics Shop
# 8             Coffee Shop  Vietnamese Restaurant          Grocery Store
# 9                    Bank          Grocery Store              Gift Shop
# 10                    Gym          Grocery Store  General Entertainment
# 12                   Pool    Shanghai Restaurant          Grocery Store
# 13   Fast Food Restaurant          Shopping Mall     Chinese Restaurant
# 15   Other Great Outdoors            Pizza Place               Pharmacy
#
#         10th Most Common Venue
# 2               Discount Store
# 3          Fried Chicken Joint
# 5               Discount Store
# 6          Fried Chicken Joint
# 7                    Gift Shop
# 8        General Entertainment
# 9                       Bakery
# 10         Fried Chicken Joint
# 12                Skating Rink
# 13             College Stadium
# 15  Construction & Landscaping

# %%
scarb_merged_cleaned.loc[scarb_merged_cleaned['Cluster Labels'] == 1, scarb_merged_cleaned.columns[[1] + list(range(5, scarb_merged_cleaned.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 14  Scarborough             1.0              Pharmacy  Vietnamese Restaurant
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14  Construction & Landscaping         Grocery Store             Gift Shop
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 14  General Entertainment   Fried Chicken Joint  Fast Food Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 14        Discount Store       Department Store

# %%
scarb_merged_cleaned.loc[scarb_merged_cleaned['Cluster Labels'] == 2, scarb_merged_cleaned.columns[[1] + list(range(5, scarb_merged_cleaned.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 11  Scarborough             2.0           Auto Garage     Convenience Store
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11  Construction & Landscaping                   Gym         Grocery Store
#
#    6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 11             Gift Shop  General Entertainment   Fried Chicken Joint
#
#    9th Most Common Venue 10th Most Common Venue
# 11  Fast Food Restaurant         Discount Store

# %%
scarb_merged_cleaned.loc[scarb_merged_cleaned['Cluster Labels'] == 3, scarb_merged_cleaned.columns[[1] + list(range(5, scarb_merged_cleaned.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 4  Scarborough             3.0            Playground                 Trail
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 4       College Stadium         Grocery Store             Gift Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4  General Entertainment   Fried Chicken Joint  Fast Food Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 4        Discount Store       Department Store

# %%
scarb_merged_cleaned.loc[scarb_merged_cleaned['Cluster Labels'] == 4, scarb_merged_cleaned.columns[[1] + list(range(5, scarb_merged_cleaned.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough             4.0        History Museum                   Bar
#
#         3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1  Construction & Landscaping                   Gym         Grocery Store
#
#   6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 1             Gift Shop  General Entertainment   Fried Chicken Joint
#
#   9th Most Common Venue 10th Most Common Venue
# 1  Fast Food Restaurant         Discount Store
